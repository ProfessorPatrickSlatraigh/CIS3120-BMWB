# %% [markdown]
# <a href="https://colab.research.google.com/github/ProfessorPatrickSlatraigh/CIS3120-BMWB/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Level One Heading

# %% [markdown]
# ## Hello World Program

# %% [markdown]
# My Hello World program now works.

# %%
print("Hello World!")

# %%
print("Hello again'")
